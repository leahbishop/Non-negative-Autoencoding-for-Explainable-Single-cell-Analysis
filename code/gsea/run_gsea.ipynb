# %%
# Setup

# Use a personal library (no sudo needed)
dir.create("~/Rlibs", recursive = TRUE, showWarnings = FALSE)
.libPaths(c("~/Rlibs", .libPaths()))

# Make sure CRAN is set (some HPC images don’t have it)
options(repos = c(CRAN = "https://cloud.r-project.org"))

# Install the missing CRAN dep
install.packages("S7")

# Install Bioconductor manager if needed
if (!requireNamespace("BiocManager", quietly = TRUE)) {
  install.packages("BiocManager")
}

# Install fgsea + BiocParallel from Bioconductor
BiocManager::install(c("fgsea", "BiocParallel"), ask = FALSE, update = TRUE)

# (Optional but often needed)
install.packages(c("readr","dplyr","tidyr","ggplot2"))
# Out:
# Installing package into ‘/mnt/home/bisholea/Rlibs’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("S7"):
# “installation of package ‘S7’ had non-zero exit status”
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cloud.r-project.org
#
# Bioconductor version 3.20 (BiocManager 1.30.26), R 4.4.1 (2024-06-14)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'fgsea' 'BiocParallel'”
# Old packages: 'magrittr', 'Matrix', 'reticulate', 'SeuratObject', 'tibble',
#   'utf8'
#
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘magrittr’ had non-zero exit status”
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘Matrix’ had non-zero exit status”
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘utf8’ had non-zero exit status”
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘reticulate’ had non-zero exit status”
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘SeuratObject’ had non-zero exit status”
# Warning message in install.packages(update[instlib == l, "Package"], l, contriburl = contriburl, :
# “installation of package ‘tibble’ had non-zero exit status”
# Installing packages into ‘/mnt/home/bisholea/Rlibs’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages(c("readr", "dplyr", "tidyr", "ggplot2")):
# “installation of package ‘readr’ had non-zero exit status”
# Warning message in install.packages(c("readr", "dplyr", "tidyr", "ggplot2")):
# “installation of package ‘dplyr’ had non-zero exit status”
# Warning message in install.packages(c("readr", "dplyr", "tidyr", "ggplot2")):
# “installation of package ‘tidyr’ had non-zero exit status”

# %%
# Get common genes between AE, NMF, and MSigDB for GSEA

suppressPackageStartupMessages({
  library(readr); library(dplyr); library(msigdbr); library(stringr)
})

base_dir <- "/mnt/projects/debruinz_project/bisholea/capstone/gsea"

# Load W (genes × factors)
ae_var  <- read_csv(file.path(base_dir, "ae_adata_var_metadata_unique.csv"),  show_col_types = FALSE)
ae_W    <- read_csv(file.path(base_dir, "ae_adata_var_embeddings_unique.csv"),show_col_types = FALSE)
nmf_var <- read_csv(file.path(base_dir, "als_nmf_var_metadata_unique.csv"),   show_col_types = FALSE)
nmf_W   <- read_csv(file.path(base_dir, "als_nmf_var_embeddings_unique.csv"), show_col_types = FALSE)

stopifnot(nrow(ae_var) == nrow(ae_W), nrow(nmf_var) == nrow(nmf_W))

# Gene symbols (uppercased for robust matching)
AE_GENES  <- toupper(str_trim(ae_var$feature_name))
NMF_GENES <- toupper(str_trim(nmf_var$feature_name))
MSIG      <- msigdbr(species = "Homo sapiens", collection = "C5")
MSIG_GENES <- unique(toupper(MSIG$gene_symbol))

cat("AE genes:", length(unique(AE_GENES)),
    "NMF genes:", length(unique(NMF_GENES)),
    "MSigDB genes:", length(MSIG_GENES), "\n")

UNIVERSE <- Reduce(intersect, list(unique(AE_GENES), unique(NMF_GENES), MSIG_GENES))
cat("Common gene universe size:", length(UNIVERSE), "genes\n")

# Filter rows in W to universe
ae_idx  <- AE_GENES  %in% UNIVERSE
nmf_idx <- NMF_GENES %in% UNIVERSE
ae_W_common  <- ae_W[ae_idx, , drop = FALSE]
nmf_W_common <- nmf_W[nmf_idx, , drop = FALSE]
ae_genes_common  <- AE_GENES[ae_idx]
nmf_genes_common <- NMF_GENES[nmf_idx]

# Restrict pathway list to universe (optional but tidy)
msig_list_common <- split(MSIG$gene_symbol, MSIG$gs_name)
msig_list_common <- lapply(msig_list_common, function(g) intersect(toupper(g), UNIVERSE))
msig_list_common <- msig_list_common[lengths(msig_list_common) > 0]

cat("Pathways with ≥1 gene in universe:", length(msig_list_common), "\n")

# Save everything for the analysis chunk
saveRDS(list(
  ae_W_common = ae_W_common,
  nmf_W_common = nmf_W_common,
  ae_genes_common = ae_genes_common,
  nmf_genes_common = nmf_genes_common,
  universe = UNIVERSE,
  msig_list_common = msig_list_common
), file.path(base_dir, "common_gene_preproc.rds"))
# Out:
# Warning message:
# “package ‘msigdbr’ was built under R version 4.4.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.4.3”
# AE genes: 40508 NMF genes: 60664 MSigDB genes: 19549
# Common gene universe size: 19165 genes
# Pathways with ≥1 gene in universe: 16228

# %%
# Run GSEA for both AE and NMF on common genes

suppressPackageStartupMessages({
  library(dplyr); library(tidyr); library(fgsea); library(BiocParallel); library(readr)
})

base_dir <- "/mnt/projects/debruinz_project/bisholea/capstone/gsea"
pp <- readRDS(file.path(base_dir, "common_gene_preproc.rds"))

run_fgsea_on_W <- function(W, genes, pathways, prefix) {
  # W is genes×factors, `genes` are row-matched symbols (already in universe)
  stopifnot(nrow(W) == length(genes))
  coln <- colnames(W)
  bp <- BiocParallel::MulticoreParam(workers = 30)

  res <- lapply(seq_along(coln), function(i) {
    f <- coln[i]
    stats <- as.numeric(W[[i]])
    names(stats) <- genes
    stats <- sort(stats[stats != 0], decreasing = TRUE)  # drop zeros, rank desc
    if (!length(stats)) return(tibble::tibble(pathway=character(), NES=numeric(), padj=numeric(), factor=f))
    fg <- fgsea(pathways, stats, eps=0, scoreType="pos", minSize=5, maxSize=500, BPPARAM=bp)
    dplyr::transmute(fg, pathway, NES, padj, factor = f)
  })
  comb <- dplyr::bind_rows(res)

  nes  <- comb %>%
    tidyr::pivot_wider(id_cols = pathway, names_from = factor, values_from = NES) %>%
    dplyr::arrange(pathway)
  padj <- comb %>%
    tidyr::pivot_wider(id_cols = pathway, names_from = factor, values_from = padj) %>%
    dplyr::arrange(pathway)
  counts <- comb %>% mutate(sig = padj < 0.01) %>% count(factor, wt=sig, name="n_sig") %>% arrange(desc(n_sig))

  readr::write_csv(padj,  file.path(base_dir, sprintf("%s_padj_matrix_allFactors_common_genes.csv", prefix)))
  readr::write_csv(nes,   file.path(base_dir, sprintf("%s_NES_matrix_allFactors_common_genes.csv", prefix)))
  readr::write_csv(counts,file.path(base_dir, sprintf("%s_factor_gsea_counts_common_genes.csv", prefix)))

  message(prefix, ": factors=", ncol(W), ", factors with ≥1 sig=", sum(counts$n_sig>0),
          ", total sig pairs=", sum(counts$n_sig))
  invisible(list(combined=comb, counts=counts))
}

ae_out  <- run_fgsea_on_W(pp$ae_W_common,  pp$ae_genes_common,  pp$msig_list_common, "ae")
nmf_out <- run_fgsea_on_W(pp$nmf_W_common, pp$nmf_genes_common, pp$msig_list_common, "nmf")
# Out:
# Warning message:
# “package ‘BiocParallel’ was built under R version 4.4.3”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# ae: factors=256, factors with ≥1 sig=44, total sig pairs=720
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.56% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.71% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.65% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.41% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.29% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.96% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (70.37% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.59% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.35% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.01% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (86.57% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (76.75% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (73.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.87% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.2% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.35% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (16.79% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.85% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.56% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.44% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (74.2% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.36% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.74% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.76% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.19% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.91% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (76.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.68% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.77% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.34% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (54.72% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (34.12% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (85.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.55% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (65.49% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (73.93% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.96% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.72% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (57.51% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.68% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (47.21% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.92% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (10.79% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (62.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.24% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (85.88% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.71% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (45.27% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (21.58% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.81% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (43.14% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.74% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (47.67% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.35% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.53% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.38% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (56.97% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.33% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.83% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (76.5% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.83% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.95% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.65% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.51% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (13.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.47% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.85% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.54% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (74.6% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (62.22% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.65% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.61% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (32.62% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.24% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (17.96% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (61.37% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (72.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.83% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.27% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (85.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (85.82% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (56.46% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (47.46% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (46.06% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (85.12% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.86% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.39% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.28% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.8% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.97% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.84% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.91% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (9.76% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.46% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.57% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.92% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.48% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.34% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (74.38% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (45.45% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.09% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.7% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.95% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.2% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.1% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (69.84% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.81% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.74% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.7% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.14% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.77% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (65.71% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.82% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.07% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.29% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (70.97% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.9% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.51% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (66.8% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.28% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.34% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (69.67% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.87% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (47.79% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.71% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.42% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (47.16% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.24% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.51% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.69% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.96% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.49% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (71.83% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (59.12% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (22.95% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (51.44% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.38% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.07% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (57.3% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.24% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (72.74% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (30.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.46% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (44.3% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.49% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.73% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.97% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (4.63% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.76% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (58.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (75.17% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (76.74% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.73% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (84.85% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (54.84% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.38% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (23.93% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (83.82% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (71.73% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (73.37% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (13.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (8.16% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (55.32% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.86% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.34% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (34.62% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (82.37% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (81.49% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (77.01% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (74.11% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.97% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (78.9% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.93% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (35.85% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (69.89% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (31.5% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (79.86% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (72.59% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (68.58% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (69.01% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (15.66% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (8.93% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (41.5% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (80.38% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (23.12% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# nmf: factors=200, factors with ≥1 sig=185, total sig pairs=26601

# %%
# Save as RDS for plotting 

saveRDS(list(
  ae_W_common      = pp$ae_W_common,
  nmf_W_common     = pp$nmf_W_common,
  ae_genes_common  = pp$ae_genes_common,
  nmf_genes_common = pp$nmf_genes_common,
  msig_list_common = pp$msig_list_common,
  ae_combined      = ae_out$combined,  # optional but useful
  nmf_combined     = nmf_out$combined, # optional but useful
  minSize          = 5,                 # record params used
  alpha            = 0.01,
  ae_counts        = ae_out$counts,   # per-factor n_sig for AE
  nmf_counts       = nmf_out$counts   # per-factor n_sig for NMF
), file.path(base_dir, "gsea_common_for_plots.rds"))

# %%
suppressPackageStartupMessages({
  library(readr); library(dplyr); library(tidyr); library(stringr)
})

base_dir <- "/mnt/projects/debruinz_project/bisholea/capstone/gsea"

summarize_model <- function(model) {
  nes_file  <- file.path(base_dir, sprintf("%s_NES_matrix_allFactors_common_genes.csv",  model))
  padj_file <- file.path(base_dir, sprintf("%s_padj_matrix_allFactors_common_genes.csv", model))
  fdr <- 0.05

  nes_mat  <- readr::read_csv(nes_file,  show_col_types = FALSE)
  padj_mat <- readr::read_csv(padj_file, show_col_types = FALSE)

  # Ensure 'pathway' exists and column names are unique/sane
  stopifnot("pathway" %in% names(nes_mat), "pathway" %in% names(padj_mat))
  names(nes_mat)  <- make.unique(names(nes_mat))
  names(padj_mat) <- make.unique(names(padj_mat))

  # Only use columns that are in BOTH matrices (excluding 'pathway')
  factor_cols <- setdiff(intersect(names(nes_mat), names(padj_mat)), "pathway")
  if (!length(factor_cols)) stop("No overlapping factor columns between NES and padj matrices.")

  # Long forms for the SAME set of factors, then deduplicate (pathway, factor)
  nes_long <- nes_mat |>
    tidyr::pivot_longer(all_of(factor_cols), names_to = "factor", values_to = "NES") |>
    dplyr::group_by(pathway, factor) |>
    dplyr::summarise(NES = suppressWarnings(mean(NES, na.rm = TRUE)), .groups = "drop")

  padj_long <- padj_mat |>
    tidyr::pivot_longer(all_of(factor_cols), names_to = "factor", values_to = "padj") |>
    dplyr::group_by(pathway, factor) |>
    dplyr::summarise(padj = suppressWarnings(min(padj, na.rm = TRUE)), .groups = "drop")

  # Safe one-to-one join now
  res <- nes_long |>
    dplyr::left_join(padj_long, by = c("pathway", "factor")) |>
    dplyr::mutate(
      tested = !is.na(padj),
      sig    = tested & (padj < fdr)
    )

  safe_which_min <- function(x) {
    if (length(x) == 0L || all(is.na(x))) return(NA_integer_)
    which.min(replace(x, is.na(x), Inf))
  }

  factor_counts <- res |>
    dplyr::group_by(factor) |>
    dplyr::summarise(
      n_tested     = sum(tested, na.rm = TRUE),
      n_sig        = sum(sig,     na.rm = TRUE),
      frac_sig     = ifelse(n_tested > 0, n_sig / n_tested, NA_real_),
      best_idx     = safe_which_min(padj),
      best_padj    = suppressWarnings(min(padj, na.rm = TRUE)),
      best_pathway = if (!is.na(best_idx)) pathway[best_idx] else NA_character_,
      best_NES     = if (!is.na(best_idx)) NES[best_idx]     else NA_real_,
      .groups = "drop"
    ) |>
    dplyr::arrange(dplyr::desc(n_sig)) |>
    dplyr::select(-best_idx)

  cat("\n=== GSEA Summary (COMMON GENES, FDR < 0.05) ===\n")
  cat("Model:", toupper(model), "\n")
  cat("Factors:", nrow(factor_counts), "\n")
  cat("Factors with ≥1 enriched GO term:", sum(factor_counts$n_sig > 0, na.rm = TRUE), "\n")
  cat("Total enriched factor–pathway pairs:", sum(factor_counts$n_sig, na.rm = TRUE), "\n\n")

  stats <- factor_counts$n_sig
  print(tibble::tibble(
    mean   = mean(stats), median = median(stats), sd  = sd(stats),
    min    = min(stats),  q1     = unname(quantile(stats, 0.25)),
    q3     = unname(quantile(stats, 0.75)), max = max(stats)
  ))
  cat("\nTop 10 factors by # enriched GO terms:\n")
  print(dplyr::slice_head(factor_counts, n = 10))

  invisible(factor_counts)
}

summarize_model("ae")
summarize_model("nmf")
# Out:
# === GSEA Summary (COMMON GENES, FDR < 0.05) ===
# Model: AE
# Factors: 256
# Factors with ≥1 enriched GO term: 83
# Total enriched factor–pathway pairs: 1740
#
# # A tibble: 1 × 7
#    mean median    sd   min    q1    q3   max
#   <dbl>  <dbl> <dbl> <int> <dbl> <dbl> <int>
# 1  6.80      0  30.4     0     0  1.25   375
#
# Top 10 factors by # enriched GO terms:
# # A tibble: 10 × 7
#    factor n_tested n_sig frac_sig best_padj best_pathway                best_NES
#    <chr>     <int> <int>    <dbl>     <dbl> <chr>                          <dbl>
#  1 F179      11494   375  0.0326   1.17e- 8 HP_MITOCHONDRIAL_MYOPATHY       1.55
#  2 F102      11494   213  0.0185   6.78e- 3 GOBP_REGULATION_OF_NUCLEOC…     1.53
#  3 F129      11494   145  0.0126   1.94e-21 GOMF_STRUCTURAL_MOLECULE_A…     1.13
#  4 F198      11494    90  0.00783  6.74e-11 GOBP_ATP_BIOSYNTHETIC_PROC…     1.41
#  5 F134      11494    86  0.00748  1.02e- 8 GOCC_SYNAPSE                    1.15
#  6 F64       11494    74  0.00644  1.93e- 6 HP_ABNORMALITY_OF_VISION        1.25
#  7 F105      11494    62  0.00539  4.08e- 3 GOBP_ACTIN_MEDIATED_CELL_C…     1.72
#  8 F117      11494    49  0.00426  1.72e- 2 GOBP_PROTEIN_DEPHOSPHORYLA…     1.84
#  9 F200      11494    49  0.00426  2.23e- 2 GOBP_ALPHA_BETA_T_CELL_ACT…     1.86
# 10 F48       11494    44  0.00383  1.55e- 6 GOBP_RNA_PROCESSING             1.12
#
# === GSEA Summary (COMMON GENES, FDR < 0.05) ===
# Model: NMF
# Factors: 200
# Factors with ≥1 enriched GO term: 193
# Total enriched factor–pathway pairs: 49318
#
# # A tibble: 1 × 7
#    mean median    sd   min    q1    q3   max
#   <dbl>  <dbl> <dbl> <int> <dbl> <dbl> <int>
# 1  247.   212.  197.     0    85  392.   979
#
# Top 10 factors by # enriched GO terms:
# # A tibble: 10 × 7
#    factor n_tested n_sig frac_sig best_padj best_pathway                best_NES
#    <chr>     <int> <int>    <dbl>     <dbl> <chr>                          <dbl>
#  1 F107      15828   979   0.0619  1.28e-21 GOCC_CELL_CELL_JUNCTION         1.59
#  2 F64       15828   780   0.0493  1.51e-16 GOCC_EXTERNAL_ENCAPSULATIN…     1.59
#  3 F139      15828   745   0.0471  1.02e-14 GOBP_INFLAMMATORY_RESPONSE      1.38
#  4 F77       15828   738   0.0466  3.93e-26 GOCC_SYNAPTIC_MEMBRANE          1.52
#  5 F58       15828   683   0.0432  1.67e-21 GOCC_EXTERNAL_ENCAPSULATIN…     1.53
#  6 F41       15828   647   0.0409  1.39e-22 GOCC_SYNAPTIC_MEMBRANE          1.57
#  7 F167      15828   622   0.0393  2.19e-19 GOCC_SYNAPTIC_MEMBRANE          1.46
#  8 F11       15828   616   0.0389  5.36e- 8 GOCC_SECRETORY_GRANULE          1.38
#  9 F12       15828   616   0.0389  2.03e-20 GOCC_AXON                       1.48
# 10 F183      15828   590   0.0373  5.54e- 7 GOBP_WOUND_HEALING              1.37

# %%
library(readr); library(dplyr); library(tidyr); library(tibble)

ae_path  <- file.path(base_dir, "ae_padj_matrix_allFactors_common_genes.csv")
nmf_path <- file.path(base_dir, "nmf_padj_matrix_allFactors_common_genes.csv")

# Show just the column names
ae_cols  <- names(readr::read_csv(ae_path, n_max = 0, show_col_types = FALSE))
nmf_cols <- names(readr::read_csv(nmf_path, n_max = 0, show_col_types = FALSE))
ae_cols; nmf_cols

# Print first few rows (as a tibble) to see what's actually in there
readr::read_csv(ae_path, n_max = 5, show_col_types = FALSE)
readr::read_csv(nmf_path, n_max = 5, show_col_types = FALSE)
# Out:
#   [1] "pathway" "F1"      "F2"      "F3"      "F4"      "F5"      "F6"
#   [8] "F7"      "F8"      "F9"      "F10"     "F11"     "F12"     "F13"
#  [15] "F14"     "F15"     "F16"     "F17"     "F18"     "F19"     "F20"
#  [22] "F21"     "F22"     "F23"     "F24"     "F25"     "F26"     "F27"
#  [29] "F28"     "F29"     "F30"     "F31"     "F32"     "F33"     "F34"
#  [36] "F35"     "F36"     "F37"     "F38"     "F39"     "F40"     "F41"
#  [43] "F42"     "F43"     "F44"     "F45"     "F46"     "F47"     "F48"
#  [50] "F49"     "F50"     "F51"     "F52"     "F53"     "F54"     "F55"
#  [57] "F56"     "F57"     "F58"     "F59"     "F60"     "F61"     "F62"
#  [64] "F63"     "F64"     "F65"     "F66"     "F67"     "F68"     "F69"
#  [71] "F70"     "F71"     "F72"     "F73"     "F74"     "F75"     "F76"
#  [78] "F77"     "F78"     "F79"     "F80"     "F81"     "F82"     "F83"
#  [85] "F84"     "F85"     "F86"     "F87"     "F88"     "F89"     "F90"
#  [92] "F91"     "F92"     "F93"     "F94"     "F95"     "F96"     "F97"
#  [99] "F98"     "F99"     "F100"    "F101"    "F102"    "F103"    "F104"
# [106] "F105"    "F106"    "F107"    "F108"    "F109"    "F110"    "F111"
# [113] "F112"    "F113"    "F114"    "F115"    "F116"    "F117"    "F118"
# [120] "F119"    "F120"    "F121"    "F122"    "F123"    "F124"    "F125"
# [127] "F126"    "F127"    "F128"    "F129"    "F130"    "F131"    "F132"
# [134] "F133"    "F134"    "F135"    "F136"    "F137"    "F138"    "F139"
# [141] "F140"    "F141"    "F142"    "F143"    "F144"    "F145"    "F146"
# [148] "F147"    "F148"    "F149"    "F150"    "F151"    "F152"    "F153"
# [155] "F154"    "F155"    "F156"    "F157"    "F158"    "F159"    "F160"
# [162] "F161"    "F162"    "F163"    "F164"    "F165"    "F166"    "F167"
# [169] "F168"    "F169"    "F170"    "F171"    "F172"    "F173"    "F174"
# [176] "F175"    "F176"    "F177"    "F178"    "F179"    "F180"    "F181"
# [183] "F182"    "F183"    "F184"    "F185"    "F186"    "F187"    "F188"
# [190] "F189"    "F190"    "F191"    "F192"    "F193"    "F194"    "F195"
# [197] "F196"    "F197"    "F198"    "F199"    "F200"    "F201"    "F202"
# [204] "F203"    "F204"    "F205"    "F206"    "F207"    "F208"    "F209"
# [211] "F210"    "F211"    "F212"    "F213"    "F214"    "F215"    "F216"
# [218] "F217"    "F218"    "F219"    "F220"    "F221"    "F222"    "F223"
# [225] "F224"    "F225"    "F226"    "F227"    "F228"    "F229"    "F230"
# [232] "F231"    "F232"    "F233"    "F234"    "F235"    "F236"    "F237"
# [239] "F238"    "F239"    "F240"    "F241"    "F242"    "F243"    "F244"
# [246] "F245"    "F246"    "F247"    "F248"    "F249"    "F250"    "F251"
# [253] "F252"    "F253"    "F254"    "F255"    "F256"
#   [1] "pathway" "F1"      "F2"      "F3"      "F4"      "F5"      "F6"
#   [8] "F7"      "F8"      "F9"      "F10"     "F11"     "F12"     "F13"
#  [15] "F14"     "F15"     "F16"     "F17"     "F18"     "F19"     "F20"
#  [22] "F21"     "F22"     "F23"     "F24"     "F25"     "F26"     "F27"
#  [29] "F28"     "F29"     "F30"     "F31"     "F32"     "F33"     "F34"
#  [36] "F35"     "F36"     "F37"     "F38"     "F39"     "F40"     "F41"
#  [43] "F42"     "F43"     "F44"     "F45"     "F46"     "F47"     "F48"
#  [50] "F49"     "F50"     "F51"     "F52"     "F53"     "F54"     "F55"
#  [57] "F56"     "F57"     "F58"     "F59"     "F60"     "F61"     "F62"
#  [64] "F63"     "F64"     "F65"     "F66"     "F67"     "F68"     "F69"
#  [71] "F70"     "F71"     "F72"     "F73"     "F74"     "F75"     "F76"
#  [78] "F77"     "F78"     "F79"     "F80"     "F81"     "F82"     "F83"
#  [85] "F84"     "F85"     "F86"     "F87"     "F88"     "F89"     "F90"
#  [92] "F91"     "F92"     "F93"     "F94"     "F95"     "F96"     "F97"
#  [99] "F98"     "F99"     "F100"    "F101"    "F102"    "F103"    "F104"
# [106] "F105"    "F106"    "F107"    "F108"    "F109"    "F110"    "F111"
# [113] "F112"    "F113"    "F114"    "F115"    "F116"    "F117"    "F118"
# [120] "F119"    "F120"    "F121"    "F122"    "F123"    "F124"    "F125"
# [127] "F126"    "F127"    "F128"    "F129"    "F130"    "F131"    "F132"
# [134] "F133"    "F134"    "F135"    "F136"    "F137"    "F138"    "F139"
# [141] "F140"    "F141"    "F142"    "F143"    "F144"    "F145"    "F146"
# [148] "F147"    "F148"    "F149"    "F150"    "F151"    "F152"    "F153"
# [155] "F154"    "F155"    "F156"    "F157"    "F158"    "F159"    "F160"
# [162] "F161"    "F162"    "F163"    "F164"    "F165"    "F166"    "F167"
# [169] "F168"    "F169"    "F170"    "F171"    "F172"    "F173"    "F174"
# [176] "F175"    "F176"    "F177"    "F178"    "F179"    "F180"    "F181"
# [183] "F182"    "F183"    "F184"    "F185"    "F186"    "F187"    "F188"
# [190] "F189"    "F190"    "F191"    "F192"    "F193"    "F194"    "F195"
# [197] "F196"    "F197"    "F198"    "F199"    "F200"
#   pathway                                                F1 F2 F3 F4 F5 F6
# 1 GOBP_2FE_2S_CLUSTER_ASSEMBLY                           NA NA NA NA NA NA
# 2 GOBP_2_OXOGLUTARATE_METABOLIC_PROCESS                  NA NA NA NA NA NA
# 3 GOBP_3_UTR_MEDIATED_MRNA_DESTABILIZATION               NA NA NA NA NA NA
# 4 GOBP_3_UTR_MEDIATED_MRNA_STABILIZATION                 NA NA NA NA NA NA
# 5 GOBP_5S_CLASS_RRNA_TRANSCRIPTION_BY_RNA_POLYMERASE_III NA NA NA NA NA NA
#   F7        F8 F9 ⋯ F247 F248 F249      F250 F251 F252 F253 F254 F255 F256
# 1        NA NA NA ⋯ NA   NA          NA NA   NA   NA   NA   NA   NA   NA
# 2        NA NA NA ⋯ NA   NA          NA NA   NA   NA   NA   NA   NA   NA
# 3        NA NA NA ⋯ NA   NA          NA NA   NA   NA   NA   NA   NA   NA
# 4 0.9877996 NA NA ⋯  1   NA   0.8823497 NA   NA   NA   NA   NA   NA   NA
# 5        NA NA NA ⋯ NA   NA          NA NA   NA   NA   NA   NA   NA   NA
#   pathway                                          F1        F2
# 1 GOBP_10_FORMYLTETRAHYDROFOLATE_METABOLIC_PROCESS        NA 0.9663585
# 2 GOBP_2FE_2S_CLUSTER_ASSEMBLY                            NA 0.7725215
# 3 GOBP_2_OXOGLUTARATE_METABOLIC_PROCESS            0.8419336 0.9404722
# 4 GOBP_3_UTR_MEDIATED_MRNA_DESTABILIZATION         0.4827329 0.2491901
# 5 GOBP_3_UTR_MEDIATED_MRNA_STABILIZATION           0.7349244 0.9595890
#   F3        F4        F5        F6        F7        F8        F9        ⋯ F191
# 1 0.9622251        NA        NA        NA        NA        NA        NA ⋯ NA
# 2        NA 0.9460936 0.9905548 0.9136583 0.9321511        NA        NA ⋯ NA
# 3 0.9872835 0.9807538 0.8310180 0.9883880 0.8657225        NA        NA ⋯ NA
# 4 0.4266477 0.6491670 0.4422332        NA 0.9722695 0.7634538 0.3836789 ⋯ NA
# 5 0.8395008 0.2394132 0.5321413 1.0000000 1.0000000 0.8650736 0.8102550 ⋯ NA
#   F192      F193      F194      F195      F196 F197 F198      F199 F200
# 1 1.0000000        NA        NA        NA NA   NA          NA 1    NA
# 2 0.9435082        NA 0.8573874 1.0000000 NA   NA          NA 1    NA
# 3 0.9632641 1.0000000 1.0000000        NA NA   NA          NA 1    NA
# 4 0.7329049 1.0000000        NA 0.9907967 NA   NA   0.6668559 1    NA
# 5 0.8007400 0.9799712 0.7996489 1.0000000 NA   NA          NA 1    NA
